# %% [markdown]
# ### Data Analysis and Visualization
# ##### Introduction to Matplotlib & Seaborn

# %% [markdown]
# 1.  ** Why Visualize?** An introduction to the plotting landscape with Matplotlib and Seaborn.
# 2.  ** **The Foundation: Matplotlib**
#     *   Anatomy of a plot.
#     *   Creating your first `line` and `bar` plots.
# 3.  ** **The High-Level Interface: Seaborn**
#     *   Simplifying plots with less code.
#     *   Creating statistical plots like `histograms` and `boxplots`.
# 4.  ** In-Class Activity:** Visualizing Student Performance Trends.

# %% [markdown]
# ### Why Visualize?
#
# Our brains are wired to process visual information far more effectively than tables of numbers. Good plots can instantly reveal:
#
# - **Trends:** How does a value change over time?
# - **Comparisons:** How do different groups compare against each other?
# - **Distributions:** How is our data spread out? Are there outliers?
# - **Relationships:** Do two variables seem to be related?
#
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.
#
# ---

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user name\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
y_axis=[2,5,4,6,7,4]
plt.figure(figsize=(6,4))
plt.plot(y_axis)
plt.show()

# %%
import matplotlib.pyplot as plt 
x_axis=[2,4,5,6,7,8]
y_axis=["Apple","Orange","Grapes","Banana","Mango","Mango"]
plt.figure(figsize=(7,5))
plt.plot(x_axis,y_axis,color="Violet")
plt.show()

# %%
plt.plot(y_axis,x_axis)
plt.show()

# %%
dir(plt)
# Out:
# ['AbstractContextManager',
#  'Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'AxLine',
#  'Axes',
#  'BackendFilter',
#  'Button',
#  'Circle',
#  'Colorizer',
#  'ColorizingArtist',
#  'Colormap',
#  'Enum',
#  'ExitStack',
#  'Figure',
#  'FigureBase',
#  'FigureCanvasBase',
#  'FigureManagerBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'TYPE_CHECKING',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_ColorizerInterface',
#  '_NO_PYPLOT_NOTE',
#  '_REPL_DISPLAYHOOK',
#  '_ReplDisplayHook',
#  '__annotations__',
#  '__builtins__',
#  '__cached__',
#  '__conditional_annotations__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_add_pyplot_note',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_color_sequences',
#  '_colormaps',
#  '_copy_docstring_and_deprecators',
#  '_docstring',
#  '_draw_all_if_interactive',
#  '_get_backend_mod',
#  '_get_pyplot_commands',
#  '_log',
#  '_pylab_helpers',
#  '_warn_if_gui_out_of_main_thread',
#  'acorr',
#  'angle_spectrum',
#  'annotate',
#  'annotations',
#  'arrow',
#  'autoscale',
#  'autumn',
#  'available_backends',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axline',
#  'axvline',
#  'axvspan',
#  'backend_registry',
#  'bar',
#  'bar_label',
#  'barbs',
#  'barh',
#  'bone',
#  'box',
#  'boxplot',
#  'broken_barh',
#  'cast',
#  'cbook',
#  'cla',
#  'clabel',
#  'clf',
#  'clim',
#  'close',
#  'cm',
#  'cohere',
#  'color_sequences',
#  'colorbar',
#  'colormaps',
#  'connect',
#  'contour',
#  'contourf',
#  'cool',
#  'copper',
#  'csd',
#  'cycler',
#  'delaxes',
#  'disconnect',
#  'draw',
#  'draw_all',
#  'draw_if_interactive',
#  'ecdf',
#  'errorbar',
#  'eventplot',
#  'figaspect',
#  'figimage',
#  'figlegend',
#  'fignum_exists',
#  'figtext',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'flag',
#  'functools',
#  'gca',
#  'gcf',
#  'gci',
#  'get',
#  'get_backend',
#  'get_cmap',
#  'get_current_fig_manager',
#  'get_figlabels',
#  'get_fignums',
#  'get_plot_commands',
#  'get_scale_names',
#  'getp',
#  'ginput',
#  'gray',
#  'grid',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hlines',
#  'hot',
#  'hsv',
#  'importlib',
#  'imread',
#  'imsave',
#  'imshow',
#  'inferno',
#  'inspect',
#  'install_repl_displayhook',
#  'interactive',
#  'ioff',
#  'ion',
#  'isinteractive',
#  'jet',
#  'legend',
#  'locator_params',
#  'logging',
#  'loglog',
#  'magma',
#  'magnitude_spectrum',
#  'margins',
#  'matplotlib',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mlab',
#  'new_figure_manager',
#  'nipy_spectral',
#  'np',
#  'overload',
#  'pause',
#  'pcolor',
#  'pcolormesh',
#  'phase_spectrum',
#  'pie',
#  'pink',
#  'plasma',
#  'plot',
#  'plot_date',
#  'polar',
#  'prism',
#  'psd',
#  'quiver',
#  'quiverkey',
#  'rc',
#  'rcParams',
#  'rcParamsDefault',
#  'rcParamsOrig',
#  'rc_context',
#  'rcdefaults',
#  'rcsetup',
#  'requested_backend',
#  'rgrids',
#  'savefig',
#  'sca',
#  'scatter',
#  'sci',
#  'semilogx',
#  'semilogy',
#  'set_cmap',
#  'set_loglevel',
#  'setp',
#  'show',
#  'specgram',
#  'spring',
#  'spy',
#  'stackplot',
#  'stairs',
#  'stem',
#  'step',
#  'streamplot',
#  'style',
#  'subplot',
#  'subplot2grid',
#  'subplot_mosaic',
#  'subplot_tool',
#  'subplots',
#  'subplots_adjust',
#  'summer',
#  'suptitle',
#  'switch_backend',
#  'sys',
#  'table',
#  'text',
#  'thetagrids',
#  'threading',
#  'tick_params',
#  'ticklabel_format',
#  'tight_layout',
#  'time',
#  'title',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'uninstall_repl_displayhook',
#  'violinplot',
#  'viridis',
#  'vlines',
#  'waitforbuttonpress',
#  'winter',
#  'xcorr',
#  'xkcd',
#  'xlabel',
#  'xlim',
#  'xscale',
#  'xticks',
#  'ylabel',
#  'ylim',
#  'yscale',
#  'yticks']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import io

csv_data = """ProductID,ProductName,Category,Price,UnitsSold
101,Laptop,Electronics,1200,50
102,Mouse,Electronics,25,200
103,Keyboard,Electronics,75,150
104,T-Shirt,Apparel,20,300
105,Jeans,Apparel,95,120
106,Coffee Mug,Homeware,15,500
"""

df = pd.read_csv(io.StringIO(csv_data)) # Load CSV data from a string using StringIO as a file-like object

print(df)
# Out:
#    ProductID ProductName     Category  Price  UnitsSold
# 0        101      Laptop  Electronics   1200         50
# 1        102       Mouse  Electronics     25        200
# 2        103    Keyboard  Electronics     75        150
# 3        104     T-Shirt      Apparel     20        300
# 4        105       Jeans      Apparel     95        120
# 5        106  Coffee Mug     Homeware     15        500

# %%
x_axis=df['ProductName']
y_axis=df['Price']
plt.figure(figsize=(9,5))
plt.plot(x_axis,y_axis,color="Purple")
plt.title("Comparison between Price and Product Name")
plt.xlabel("Product Name")
plt.ylabel("Price")
plt.suptitle("Sales Data-2024 overview", fontsize=10)
plt.show()

# %%
plt.figure(figsize=(8, 4))

plt.bar(df['ProductName'], df['UnitsSold'], color='skyblue')

plt.show()

# %%
df=pd.read_csv("full_data.csv")
df
# Out:
#                                    Order ID Product Name       Category  \
# 0      261e3740-c0e9-42b1-bf87-881ac950fa3a     audience  Home & Garden
# 1      0b332b34-46dc-4eaf-a808-fec7e97ffbc6         such       Clothing
# 2      432e0b36-724d-4521-85ae-f66db8af8105         read       Clothing
# 3      ca20fb08-5c65-43b8-9577-3fa49913f93b        skill    Electronics
# 4      1dce189c-8c60-455f-a6f2-69bb2cb71539         cold    Electronics
# ...                                     ...          ...            ...
# 99995  67e1224d-86a1-411c-a880-69c3786a15e9          lot           Toys
# 99996  9ad2bf4d-9453-472a-ae50-9d6d2cf8e5e4       animal       Clothing
# 99997  43c58940-e1ab-4e8a-8cea-f02811904c06       simply    Electronics
# 99998  97b93cc6-93e1-487b-94d3-8b02e6f74038         lose       Clothing
# 99999  192e6ac4-2d97-4055-bec9-d0175f768ec3      nothing  Home & Garden
#
#         Price  Quantity  Total Sales                           Customer ID  \
# 0      766.85         4      3067.40  81af1248-afff-46ee-a091-81cf33d0d957
# 1      331.42         4      1325.68  f3f3f4ac-7ad0-4362-9134-383096d16ac8
# 2      708.10        10      7081.00  c4fc4269-3c1d-4b6b-ad23-d437c328d63f
# 3      774.09         2      1548.18  578e2d1a-d92a-449d-8eeb-b704110b2975
# 4      397.22         1       397.22  dc6ed196-0874-46bd-bbb9-c5534f619349
# ...       ...       ...          ...                                   ...
# 99995  777.82         2      1555.64  a38aebb9-d3b4-468b-a999-e6d26d62635f
# 99996  473.23         1       473.23  4fa8f362-4897-4633-995d-ec5acffbb4d7
# 99997  591.40         8      4731.20  190b3b11-217d-43ed-b6d2-aa55be036c85
# 99998  490.93         1       490.93  60e350b2-601a-401c-a8f7-f45e827a6594
# 99999  938.06         8      7504.48  a060dacf-962a-464c-a5c5-a5de55014e3b
#
#        Customer Age Customer Gender Purchase Date Purchase Time    Age Group  \
# 0                39            Male    25/05/2024       6:28:14        Adult
# 1                21            Male    04/05/2024      19:37:36  Young Adult
# 2                27          Female    07/05/2024      17:54:42  Young Adult
# 3                51          Female    23/05/2024      22:31:43       Senior
# 4                45          Female    15/03/2024       3:08:25        Adult
# ...             ...             ...           ...           ...          ...
# 99995            32            Male    01/05/2024       4:49:40        Adult
# 99996            48          Female    21/05/2024       9:13:18        Adult
# 99997            41            Male    25/03/2024      13:34:07        Adult
# 99998            56          Female    01/06/2024       3:09:28       Senior
# 99999            46            Male    30/05/2024      20:12:20        Adult
#
#        Price_with_Vat Membership Level  Discount_Eligible
# 0            866.5405           Bronze               True
# 1            374.5046           Bronze               True
# 2            800.1530             Gold               True
# 3            874.7217           Silver               True
# 4            448.8586           Silver              False
# ...               ...              ...                ...
# 99995        878.9366           Bronze              False
# 99996        534.7499           Bronze               True
# 99997        668.2820           Bronze               True
# 99998        554.7509             Gold              False
# 99999       1060.0078             Gold              False
#
# [100000 rows x 15 columns]

# %%
plt.figure(figsize=(15,9))
x_axis=df['Purchase Date'][0:100]
y_axis=df['Total Sales'][0:100]
plt.bar(x_axis,y_axis,color="violet")
plt.ylabel("Units Sold")
plt.title("Units Sold by Product")
plt.xticks(rotation=90,ha='right') #Horizontal alignment of the label; aligns text to the right side so it doesn’t overlap the axis
plt.tight_layout()# Adjust layout automatically
plt.show()

# %%
# Group by Category, Sum the Total Sales
cat_performance = df.groupby('Category')[['Total Sales','Price']].sum().reset_index()
display(cat_performance)
# Out:
#         Category  Total Sales        Price
# 0          Books  60820086.17  11064566.47
# 1       Clothing  61071489.36  11130159.19
# 2    Electronics  59955937.12  10936573.42
# 3  Home & Garden  60670371.57  11009736.91
# 4           Toys  60274785.96  10914000.35

# %%
plt.figure(figsize=(15,9))
bars=plt.bar(cat_performance['Category'],cat_performance['Total Sales'],color="Purple")
# Loop through each bar to get height and width
for bar in bars:
    height = bar.get_height()  # value of the bar
    width = bar.get_width()    # width of the bar
    print(f"Bar: {bar.get_x()} - Height: {height}, Width: {width}")
plt.show()
# Out:
# Bar: -0.4 - Height: 60820086.17, Width: 0.8
# Bar: 0.6 - Height: 61071489.36, Width: 0.8
# Bar: 1.6 - Height: 59955937.12, Width: 0.8
# Bar: 2.6 - Height: 60670371.57, Width: 0.8
# Bar: 3.6 - Height: 60274785.96, Width: 0.8

# %% [markdown]
# ## 📊 Quick Decision Guide
#
# | Plot Type   | Best For                          | Example Use Case                          |
# |------------|----------------------------------|-------------------------------------------|
# | Line Plot  | Trends over time                  | Stock prices, website traffic             |
# | Bar Plot   | Comparing categories              | Sales by product, survey results          |
# | Scatter Plot | Relationships between variables | Height vs. Weight, Age vs. Income         |
# | Histogram  | Distribution of single variable   | Age distribution, exam scores             |
# | Box Plot   | Statistical summary               | Comparing salaries across departments     |
# | Heatmap    | Matrix / correlation data         | Correlation matrix, confusion matrix      |
# | Pie Chart  | Proportions of a whole             | Market share, budget allocation           |

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample data - Monthly sales over a year
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales_2023 = [120, 135, 150, 165, 180, 200,
              190, 210, 220, 230, 250, 300]
sales_2024 = [130, 145, 160, 170, 185, 210,
              200, 220, 235, 245, 265, 320]

sales_2025 = [150, 125, 160, 800, 185, 310,
              200, 240, 235, 200, 265, 370]
plt.figure(figsize=(12, 6))
plt.plot(months, sales_2023, marker='o', linewidth=2, label='2023 Sales', color='blue')
plt.plot(months, sales_2024, marker='s', linewidth=2, label='2024 Sales', color='red', linestyle='-.')
plt.plot(months, sales_2025, marker='D', linewidth=2, label='2024 Sales', color='green', linestyle='--')

plt.suptitle('Monthly Sales Comparison (2023 vs 2024 vs 2025)', fontsize=14, fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales (in thousands $)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample data - Monthly sales over a year
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales_2023 = [120, 135, 150, 165, 180, 200,
              190, 210, 220, 230, 250, 300]
sales_2024 = [130, 145, 160, 170, 185, 210,
              200, 220, 235, 245, 265, 320]

plt.figure(figsize=(12, 6))
plt.plot(months, sales_2023, marker='o', linewidth=2, label='2023 Sales', color='blue')
plt.plot(months, sales_2024, marker='s', linewidth=2, label='2024 Sales', color='red', linestyle='-.')


plt.suptitle('Monthly Sales Comparison (2023 vs 2024)', fontsize=14, fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales (in thousands $)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# | Marker | Description |
# |------|------------|
# | `'.'` | Point |
# | `','` | Pixel |
# | `'o'` | Circle |
# | `'v'` | Triangle down |
# | `'^'` | Triangle up |
# | `'<'` | Triangle left |
# | `'>'` | Triangle right |
# | `'1'` | Tri-down |
# | `'2'` | Tri-up |
# | `'3'` | Tri-left |
# | `'4'` | Tri-right |
# | `'s'` | Square |
# | `'p'` | Pentagon |
# | `'*'` | Star |
# | `'h'` | Hexagon 1 |
# | `'H'` | Hexagon 2 |
# | `'+'` | Plus |
# | `'x'` | X |
# | `'D'` | Diamond |
# | `'d'` | Thin diamond |
# | `'_'` | Horizontal line |
# | `None` | No marker |
# | `' '` | No marker |
# | `''` | No marker |

# %%
# Multiple subplots for different metrics
_, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Simple line plot
axes[0, 0].plot(months, sales_2023)
axes[0, 0].set_title('Simple Line Plot')

# 2. Area plot (filled under line)
axes[0, 1].fill_between(months, sales_2023, alpha=0.3)
axes[0, 1].plot(months, sales_2023, linewidth=2)
axes[0, 1].set_title('Area Plot')

# 3. Step plot
axes[1, 0].step(months, sales_2023, where='mid')
axes[1, 0].set_title('Step Plot')

# 4. Stacked area plot
axes[1, 1].stackplot(months, sales_2023, sales_2024,sales_2025,
                      labels=['2023', '2024'], alpha=0.7)
axes[1, 1].set_title('Stacked Area Plot')
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %%
# Sample data - Product sales
products = ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Keyboard']
sales_q1 = [150, 300, 200, 120, 80]
sales_q2 = [180, 320, 210, 140, 90]

x = np.arange(len(products))
width = 0.35


plt.figure(figsize=(10, 6))
bars1 = plt.bar(x - width/2, sales_q1, width,
                label='Q1 Sales', color='skyblue', edgecolor='black')
bars2 = plt.bar(x + width/2, sales_q2, width,
                label='Q2 Sales', color='lightcoral', edgecolor='black')


plt.title('Product Sales by Quarter', fontsize=14, fontweight='bold')
plt.xlabel('Products', fontsize=12)
plt.ylabel('Units Sold', fontsize=12)
plt.xticks(x, products)
plt.legend()

plt.yticks(np.arange(0, 361, 20))


# Add value labels on bars
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 5,
                 f'{int(height)}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Sample data
categories = ['A', 'B', 'C', 'D', 'E']
values1 = [25, 40, 30, 35, 20]
values2 = [30, 35, 1, 40, 30]

# 1. Horizontal bar plot
axes[0, 0].barh(categories, values1, color='lightblue')
axes[0, 0].set_title('Horizontal Bar Plot')


# 2. Stacked bar plot
axes[0, 1].bar(categories, values1, label='Group 1', color='lightblue')
axes[0, 1].bar(categories, values2, bottom=values1,
               label='Group 2', color='lightcoral')
axes[0, 1].set_title('Stacked Bar Plot')
axes[0, 1].legend()


# 3. Grouped bar plot
x = np.arange(len(categories))
width = 0.35
axes[1, 0].bar(x - width/2, values1, width, label='Group 1')
axes[1, 0].bar(x + width/2, values2, width, label='Group 2')
axes[1, 0].set_xticks(x)
axes[1, 0].set_xticklabels(categories)
axes[1, 0].set_title('Grouped Bar Plot')
axes[1, 0].legend()


# 4. Percentage bar plot
total = [v1 + v2 for v1, v2 in zip(values1, values2)]
pct1 = [v1/t*100 for v1, t in zip(values1, total)]
pct2 = [v2/t*100 for v2, t in zip(values2, total)]
axes[1, 1].bar(categories, pct1, label='Group 1 %')
axes[1, 1].bar(categories, pct2, bottom=pct1, label='Group 2 %')
axes[1, 1].set_title('Percentage Bar Plot')
axes[1, 1].set_ylabel('Percentage (%)')
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %%
# Is there a relationship between the price of an item and how many units were sold?
plt.figure(figsize=(6, 4))

plt.scatter(df['Price'], df['UnitsSold'], marker='o', color='green')

plt.title('Price vs. Units Sold')
plt.xlabel('Price ($)')
plt.ylabel('Units Sold')
plt.show()

# %%
# Sample data - Study Hours vs Exam Scores
np.random.seed(42)
study_hours = np.random.normal(15, 2, 100)

print(study_hours)
exam_scores = 50 + 2*study_hours + np.random.randint(0, 10, 100)
# Add some noise and relationship

plt.figure(figsize=(10, 6))
scatter = plt.scatter(study_hours, exam_scores,
                     c=exam_scores, cmap='viridis',
                     s=100, alpha=0.7, edgecolors='black')

plt.title('Study Hours vs Exam Scores', fontsize=14, fontweight='bold')
plt.xlabel('Study Hours per Week', fontsize=12)
plt.ylabel('Exam Score (out of 100)', fontsize=12)
plt.colorbar(scatter, label='Exam Score')

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# [15.99342831 14.7234714  16.29537708 18.04605971 14.53169325 14.53172609
#  18.15842563 16.53486946 14.06105123 16.08512009 14.07316461 14.06854049
#  15.48392454 11.17343951 11.55016433 13.87542494 12.97433776 15.62849467
#  13.18395185 12.1753926  17.93129754 14.5484474  15.13505641 12.15050363
#  13.91123455 15.22184518 12.69801285 15.75139604 13.79872262 14.4166125
#  13.79658678 18.70455637 14.97300555 12.88457814 16.64508982 12.5583127
#  15.41772719 11.08065975 12.3436279  15.39372247 16.47693316 15.34273656
#  14.76870344 14.39779261 12.04295602 13.56031158 14.07872246 17.11424445
#  15.68723658 11.47391969 15.64816794 14.22983544 13.646156   16.22335258
#  17.06199904 16.86256024 13.32156495 14.38157525 15.66252686 16.95109025
#  14.04165152 14.62868205 12.78733005 12.60758675 16.62505164 17.71248006
#  14.85597976 17.0070658  15.72327205 13.70976049 15.72279121 18.07607313
#  14.92834792 18.12928731  9.76050979 16.64380501 15.17409414 14.4019853
#  15.18352155 11.02486217 14.56065622 15.71422514 17.95578809 13.96345956
#  13.38301279 13.99648591 16.83080424 15.65750222 13.94047959 16.02653487
#  15.1941551  16.93728998 13.59589381 14.34467571 14.21578369 12.0729701
#  15.59224055 15.52211054 15.01022691 14.53082573]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import io

csv_data = """ProductID,ProductName,Category,Price,UnitsSold
101,Laptop,Electronics,1200,50
102,Mouse,Electronics,25,200
103,Keyboard,Electronics,75,150
104,T-Shirt,Apparel,20,300
105,Jeans,Apparel,95,120
106,Coffee Mug,Homeware,15,500
"""

df = pd.read_csv(io.StringIO(csv_data)) # Load CSV data from a string using StringIO as a file-like object

print(df)
# Out:
#    ProductID ProductName     Category  Price  UnitsSold
# 0        101      Laptop  Electronics   1200         50
# 1        102       Mouse  Electronics     25        200
# 2        103    Keyboard  Electronics     75        150
# 3        104     T-Shirt      Apparel     20        300
# 4        105       Jeans      Apparel     95        120
# 5        106  Coffee Mug     Homeware     15        500

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
color = ['red', 'blue', 'green', 'orange', 'purple', 'cyan']

plt.pie(df['UnitsSold'],
       labels=df['ProductName'],colors=color,
       autopct='%1.1f%%',
       startangle=0)
plt.title('Units Sold Distribution per Product')
plt.tight_layout()  # Prevent overlap
plt.legend(loc='upper right')
plt.show()
